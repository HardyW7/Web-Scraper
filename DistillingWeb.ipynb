# %% [markdown]
# This was a challenging exercise to complete because of the diverse ways websites write their corresponding HTML information.  I was able to scrape the Seattle Parks website for relevant information but when the scraped addresses were input into the google maps API, about 15% of them gave back lat/lng coordinates for the midwest or east coast.

# %%
#Import all of the necessary modules for the code

from bs4 import BeautifulSoup
import urllib2
import re
import lxml
import csv
import json
from time import sleep

#set some variables for the url to be scraped and location of files
url = "http://www.seattle.gov/parks/listall.asp"
directory = "U:/Seattle_parks.csv"
geoDirectory = "U:/Seattle_parks_geocode.csv"

#define the geocoding function using the google maps API
def geocode(address):
    url = ("http://maps.googleapis.com/maps/api/geocode/json?"
        "sensor=false&address={0}".format(address.replace(" ", "+")))
    return json.loads(urlopen(url).read())

#Write a csv file with the names and addresses of each Seattle Park
# using beautiful soup
with open(directory, 'w') as f:
    fieldnames = ("Park_Name", "Address")
    output = csv.writer(f, delimiter=",")
    output.writerow(fieldnames)
    
    page = urllib2.urlopen(url)
    soup = BeautifulSoup(page.read())
    
    names = soup.find_all('a', href=re.compile('park_detail'))
    names = [name.contents[0].strip() for name in names]

    places = soup.find_all("td", {"width" : "43%"})
    places = [place.contents[0].strip() for place in places]
    
    for n,p in zip(names, places):
        output.writerow((n, p))
        
print "Done writing csv file"
# Out:
# Done writing csv file

# %% [markdown]
# Some of the following code was borrowed from other google users that were attempting to solve similar problems.  I was able to adapt their lines of code to my own situation.  One issue I ran into here was the need to include the sleep function near the bottom.  Without the sleep function at the end of the loop, my code output a file with only the first dozen or so records with lat/lng information and the rest are empty.

# %%
with open(directory, 'r') as f:
    reader = csv.DictReader(f, delimiter=',')
    
    with open(geoDirectory, 'w') as w:
        fields = ["Park_Name", "Address", "lat", "lng"]
        writer = csv.DictWriter(w, fieldnames=fields, delimiter=',')
        writer.writeheader()

        for line in reader:
            print "Geocoding: {0}".format(line["Address"])
            response = geocode(line["Address"] + " Seattle WA")
            if response["status"] == u"OK":
                results = response.get("results")[0]
                line["Address"] = results["formatted_address"]
                line["lat"] = results["geometry"]["location"]["lat"]
                line["lng"] = results["geometry"]["location"]["lng"]
            else:
                line["Address"] = ""
                line["lat"] = ""
                line["lng"] = ""
                print "No API info"
            sleep(.5)
            writer.writerow(line)

print "Done writing csv file"
# Out:
# Geocoding: 564 12th Ave
# Geocoding: 4400 14th Ave NW
# Geocoding: 3001 E Madison St
# Geocoding: 32nd Ave W
# Geocoding: 606  NW 76th St
# Geocoding: 723 N 35th St
# Geocoding: Lake Washington Blvd S & S Adams St
# Geocoding: 12526 27th Ave NE
# Geocoding: 1702 Alki Ave SW
# Geocoding: 5817 SW Lander St
# Geocoding: 1504 34TH Ave
# Geocoding: 2000 Martin Luther King Jr Way S
# Geocoding: 4000 Beach Dr SW
# Geocoding: 3431 Arapahoe Pl W
# Geocoding: 4120 Arroyo Dr SW
# Geocoding: 8702 Seward Park Ave S
# Geocoding: 1501 21st Ave S
# Geocoding: 4020 Fremont Ave N
# Geocoding: 2548 Delmar Dr E
# Geocoding: 8347 14th Ave NW
# Geocoding: 5701 22nd Ave NW
# Geocoding: 1702 nw 62nd St
# Geocoding: 2644 NW 60th St
# Geocoding: 7802 Banner Way NE
# Geocoding: 6425 SW Admiral Way
# Geocoding: 2614 24th Ave W
# Geocoding: 3rd Ave W & W Prospect St
# Geocoding: 1902 13th Ave S
# Geocoding: 1110 S Dearborn St
# Geocoding: 5th Ave NE & NE 103rd St
# Geocoding: 5809 15th Ave NE
# Geocoding: 8650 55th Ave S
# Geocoding: 1st to 5th Ave on Bell St
# Geocoding: Bellevue Ave E & Bellevue Pl E
# Geocoding: 2512 Elliott Ave
# Geocoding: 703 Belmont Pl E
# Geocoding: 3600 SW Admiral Way
# Geocoding: 3659 42nd Ave NE
# Geocoding: 9320 38th Ave S
# Geocoding: 1401 23rd Ave S
# Geocoding: 5420 22nd Ave NW
# Geocoding: 1215 5th Ave N
# Geocoding: 13035 Linden Ave N
# Geocoding: 14201 Linden Ave N
# Geocoding: 513 W Olympic Pl
# Geocoding: 1520 26th Ave S
# Geocoding: 1851 NW Blue Ridge Dr
# Geocoding: 1900 NW Milford Way
# Geocoding: 1606 15th Ave E
# Geocoding: 321 Broadway
# Geocoding: 815 Broadway
# Geocoding: 1730 Bradner Pl S
# Geocoding: 6000 39th Ave S
# Geocoding: Greenwood Ave N & N 122nd St
# Geocoding: 4103 NE 65th St
# Geocoding: 5201 Sand Point Way NE
# Geocoding: From NE 145 St south on Lake Washington to Ballard
# Geocoding: 1635 11th Ave
# Geocoding: 2099 California Ave SW
# Geocoding: 5200 35th Ave SW
# Geocoding: 950 NW Carkeek Park Rd
# Geocoding: 2319 Westmont Way W
# Geocoding: 3298 Perkins Ln W
# Geocoding: 5119 Palmer Ct NW
# Geocoding: 333 Pontius Ave N
# Geocoding: 3737 NE 135th St
# Geocoding: 700 S Cloverdale St
# Geocoding: 3521 Beach Dr SW
# Geocoding: Cheasty Blvd S & S Della St
# Geocoding: Cheasty Blvd S & S Della St
# Geocoding: Six-mile trail around Lake Union
# Geocoding: 700 S Cloverdale St
# Geocoding: 817 NE 43rd St
# Geocoding: 450 3rd Ave
# Geocoding: 5512 13th Ave S
# Geocoding: 2420 7th Ave W
# Geocoding: 30th Ave S & S College St
# Geocoding: 5050 SW College St
# Geocoding: 1800 Lake Washington Blvd S
# Geocoding: 1740 23rd Ave S
# Geocoding: 4721 Rainier Ave S
# Geocoding: 3330 W Commodore Way
# Geocoding: Condon Way W, W Mc Graw St. to W Blaine St.
# Geocoding: 2166 N 50th St
# Geocoding: 3701 Beach Dr SW
# Geocoding: 5206 26th Ave SW
# Geocoding: 700 Queen Anne Ave N
# Geocoding: 5849 15th Ave NE
# Geocoding: 7515 Orin Ct N
# Geocoding: 8735 19th Ave NW
# Geocoding: 9089 Holman Rd NW
# Geocoding: 1144 Sturgus Ave S
# Geocoding: 7700 25th Ave NE
# Geocoding: 4304 SW Dakota St
# Geocoding: 2800 1st Ave W
# Geocoding: 1402 Lakeside Ave S
# Geocoding: 2919 S Brandon St
# Geocoding: 4458 Delridge Way SW
# Geocoding: 100 Maiden Ln E
# Geocoding: 200 Lake Washington Blvd E
# Geocoding: 100 Dexter Ave N
# Geocoding: 3801 Discovery Park Blvd
# Geocoding: 1222 Harbor Ave SW
# Geocoding: 2100 S Jackson St
# Geocoding: 1007 12th Ave S
# Geocoding: 7900 10th Ave S
# Geocoding: 2805 SW Holden St
# Geocoding: 2802 E Park Drive East
# Geocoding: 1400 Lake Washington Blvd S
# Geocoding: 1912 Warren Ave N
# Geocoding: 10th Ave E & E Prospect St
# Geocoding: 2201 Westmont Way W
# Geocoding: 8001 Seaview Ave NW
# Geocoding: 2601 W Smith St
# Geocoding: 4503 Beach Dr SW
# Geocoding: 9827 49th Ave SW
# Geocoding: 4542 48th Ave SW
# Geocoding: 5400 Fauntleroy Way SW
# Geocoding: 2900 Fairview Ave E
# Geocoding: 1251 Fairview Ave. N
# Geocoding: 9102 Fauntleroy Way SW
# Geocoding: 3951 SW Barton St
# Geocoding: 4501 Fauntleroy Way SW
# Geocoding: 5018 Lake Washington Blvd S
# Geocoding: 712 18th Ave
# Geocoding: 1201 University St
# Geocoding: 9285 Waters Ave S
# Geocoding: 2800 S Jackson St
# Geocoding: 700 Seneca St
# Geocoding: 199 N Canal St
# Geocoding: 4357 Palatine Ave N
# Geocoding: 398 Lake Washington Blvd S
# Geocoding: 7200 12th Ave NE
# Geocoding: 537 25th Ave
# Geocoding: 2101 N Northlake Way
# Geocoding: 4316 S Genesee St
# Geocoding: 750 S Homer St
# Geocoding: 575 M L King Jr Way S
# Geocoding: 923 NW 54th St
# Geocoding: 8498 Seaview Pl NW
# Geocoding: 1200 E Howe St
# Geocoding: 7201 E Greenlake Dr N
# Geocoding: 602 N 87th St
# Geocoding: 304 NW 55th St
# Geocoding: 2600 SW Brandon St
# Geocoding: 1120 California Ave SW
# Geocoding: 779 Alder St
# Geocoding: 138 32nd Ave E
# Geocoding: 2351 Broadway E
# Geocoding: 4570 West Marginal Way SW
# Geocoding: 2700 California Ave SW
# Geocoding: 165 Highland Dr
# Geocoding: 1100 SW Cloverdale St
# Geocoding: 93 Highland Dr
# Geocoding: 423 Maynard Ave S
# Geocoding: 5234 37th Ave S
# Geocoding: 2401 E Howell St
# Geocoding: 156 Boren Ave
# Geocoding: 3298 36th Ave S
# Geocoding: 1740 Howell Pl
# Geocoding: 11203 5th Ave NE
# Geocoding: 3299 Hunter Blvd S
# Geocoding: 59th Ave S & S Norfolk St
# Geocoding: 3811 E Madison St
# Geocoding: 1701 Lakeview Blvd E
# Geocoding: 3027 17th Ave W
# Geocoding: 2501 15th Ave W
# Geocoding: 2451 Delmar Dr E
# Geocoding: 700 S Lane St
# Geocoding: 8619 45th Ave NE
# Geocoding: 1100 NE 135th St
# Geocoding: 1075 Lake Washington Blvd E
# Geocoding: 3801 Beacon Ave S
# Geocoding: 4101 Beacon Ave S
# Geocoding: 2400 S Massachusetts St
# Geocoding: 6961 37th Ave S
# Geocoding: 20th Ave S & S Judkins St
# Geocoding: 2150 S Norman St
# Geocoding: 42nd Ave SW & SW Alaska St
# Geocoding: 1150 S Atlantic St
# Geocoding: 211 W Highland Dr
# Geocoding: 5664 Keystone Pl N
# Geocoding: 9131 California Ave SW
# Geocoding: 15th Ave NE & NE 105th St
# Geocoding: 899 W Olympic Pl
# Geocoding: 7028 9th Ave NW
# Geocoding: 4531 33rd Ave W
# Geocoding: 650 Main St
# Geocoding: 9817 55th Ave S
# Geocoding: 12356 Lake City Way NE
# Geocoding: 12359 Lake City Way NE
# Geocoding: 3100 S Bradford st
# Geocoding: 860 Terry Ave N
# Geocoding: Washington Park to Seward Park
# Geocoding: 10201 Holyoke Way S
# Geocoding: 10145 Rainier Ave S
# Geocoding: 340 37th Ave E
# Geocoding: 1042 Lakeview Blvd E
# Geocoding: 4400 Lake Washington Blvd S
# Geocoding: 5013 S Angeline St
# Geocoding: 3114 Cascadia Ave S
# Geocoding: 3800 E Madison St
# Geocoding: 4099 S Horton St
# Geocoding: 4544 NE 41st St
# Geocoding: 3325 East Laurelhurst Dr NE
# Geocoding: Ravenna Ave NE & NE 100th St
# Geocoding: 4005 27th Ave W
# Geocoding: 201 Lakeside Ave. S
# Geocoding: 3525 E Terrace St
# Geocoding: 1120 15th Ave S
# Geocoding: 12th Ave NE & NE 130th St
# Geocoding: 9536 Ashworth Ave N
# Geocoding: 8011 Fauntleroy Way SW
# Geocoding: Linden Ave N & N 67th St
# Geocoding: 14043 32nd Ave NE
# Geocoding: 14499 3rd Ave NW
# Geocoding: Delridge Way SW & SW Graham St
# Geocoding: 7017 Beach Dr SW
# Geocoding: 2101 NW 77th St
# Geocoding: 2291 Fairview Ave E
# Geocoding: 1922 Taylor Ave N
# Geocoding: 4201 E Madison St
# Geocoding: 2300 43rd Ave E
# Geocoding: 1605 Madrona Dr
# Geocoding: 853 Lake Washington Blvd
# Geocoding: 3211 E Spring St
# Geocoding: E Spring St.
# Geocoding: W Howe St & Dartmouth Ave W
# Geocoding: 3500 28th Ave W
# Geocoding: 1461 Magnolia Blvd W
# Geocoding: 2518 34th Ave W
# Geocoding: W Ruffner to Elliott Bay Marina
# Geocoding: 7400 Sand Point Way NE
# Geocoding: 529 NE 103rd St
# Geocoding: 1020 NE 82nd St
# Geocoding: 1950 S Graham St
# Geocoding: 4801 Corson Ave S
# Geocoding: 9026 4th Ave S
# Geocoding: 1191 7th Ave W
# Geocoding: 6612 57th Ave S
# Geocoding: 2200 Martin Luther King Jr. way South
# Geocoding: 5400 Ballard Ave NW
# Geocoding: 5100 NE 93rd St
# Geocoding: 2600 2nd Ave N
# Geocoding: 1600 S McClellan  St
# Geocoding: 1099 McGilvra Blvd E
# Geocoding: 1425 E Madison St
# Geocoding: Westlake Ave N & Stewart St
# Geocoding: 10533 35th Ave NE
# Geocoding: 4100 Aikins Ave SW
# Geocoding: 4503 Beach Dr SW
# Geocoding: 4649 Sunnyside Ave N
# Geocoding: 330 19th Ave E
# Geocoding: 222 20th Ave E
# Geocoding: 1500 N 105th St
# Geocoding: 9612 35th Ave NE
# Geocoding: 2811 Montlake Blvd E
# Geocoding: 1618 E Calhoun St
# Geocoding: 6413 California Ave SW
# Geocoding: S Mount Baker Blvd. to S McClellan St.
# Geocoding: 2521 Lake Park Dr S
# Geocoding: 2523 Mount Claire Dr S
# Geocoding: 1403 31st Ave S
# Geocoding: 3130 Alaskan Way
# Geocoding: 35th Ave SW & SW Myrtle St
# Geocoding: 5062 SW Admiral Way
# Geocoding: 10750 30th Ave NE
# Geocoding: 551 NE 60th St
# Geocoding: 720 29th Ave
# Geocoding: 8999 24th Ave NW
# Geocoding: 600 NE Northlake Way
# Geocoding: 12718 1st Ave NE
# Geocoding: Dexter Way N, Lynn St.-Wheeler
# Geocoding: 10510 5th Ave NE
# Geocoding: 699 NE Northlake Way
# Geocoding: 6001 Seaview Ave NW
# Geocoding: 1405 Warren Ave N
# Geocoding: 117 S Washington St
# Geocoding: 2901 Western Ave
# Geocoding: 2351 W Marina Pl
# Geocoding: 39th Ave SW & SW Orchard St
# Geocoding: 4351 S Othello St
# Geocoding: 6430 Corson Ave S
# Geocoding: 5622 Park Rd NE
# Geocoding: 2401 West Viewmont Way W
# Geocoding: 650 W Highland Dr
# Geocoding: NE 40th St & NE Pacific St, Seattle
# Geocoding: 6762 Murray Ave SW
# Geocoding: 3233 E Spruce St
# Geocoding: 1951 Alaskan Way
# Geocoding: 4418 21st Ave SW
# Geocoding: 12029 14th Ave NE
# Geocoding: 11700 19th Ave NE
# Geocoding: 100 Yesler Way
# Geocoding: 600 NW 117th St
# Geocoding: 1717 26th Ave
# Geocoding: 1050 Pike St
# Geocoding: 352 Martin Luther King Jr Way
# Geocoding: 1800 S Main St
# Geocoding: 425 3rd Ave
# Geocoding: 401 24th Ave E
# Geocoding: 8400 55th Ave S
# Geocoding: 5200 26th Ave SW
# Geocoding: 1901 SW Brandon St
# Geocoding: 4767 Puget Way SW
# Geocoding: 6029 21st Ave SW
# Geocoding: Encircles Queen Anne Hill
# Geocoding: 2806 3rd Ave W
# Geocoding: 631 NE Banner Pl
# Geocoding: 8802 Rainier Ave S
# Geocoding: 230 NW 53rd St
# Geocoding: 3700 S Alaska St
# Geocoding: NE Ravenna Blvd to E Green Lake Way N
# Geocoding: 5520 Ravenna Ave NE
# Geocoding: Ravenna Ave NE & NE 54th St
# Geocoding: 6215 24th Ave NE
# Geocoding: 4633 Ravenna Ave NE
# Geocoding: 6535 Ravenna Ave NE
# Geocoding: 2251 3rd Ave
# Geocoding: 7226 12th Ave SW
# Geocoding: 950 E Roanoke St
# Geocoding: 1 E Roanoke St
# Geocoding: 2516 Eastlake Ave E
# Geocoding: 4320 4th Ave NW
# Geocoding: 4622 35th Ave SW
# Geocoding: 2850 SW Roxbury St
# Geocoding: 1726 NE 94th St
# Geocoding: 2001 NW Canoe Pl
# Geocoding: 1400 Martin Luther King Jr Way S
# Geocoding: 9053 1st Ave NW
# Geocoding: 5717 SW Stevens St
# Geocoding: 5551 SW Admiral Way
# Geocoding: 1660 Harbor Ave SW
# Geocoding: 11399 Seola Beach Dr SW
# Geocoding: 1514 E Howell St
# Geocoding: 5900 Lake Washington Blvd S
# Geocoding: 3300 Sierra Dr S
# Geocoding: 23rd Ave West
# Geocoding: 7400 Fauntleroy Way SW
# Geocoding: 1590 NW 90th St
# Geocoding: 2500 11th Ave W
# Geocoding: 9141 8th Ave S
# Geocoding: 738 S Sullivan St
# Geocoding: 3320 Fuhrman Ave E
# Geocoding: 1506 E Spring St
# Geocoding: 160 21st Ave
# Geocoding: 1500 Lakeview Blvd E
# Geocoding: 3808 Lake Washington Blvd S
# Geocoding: 2919 Beacon Ave S
# Geocoding: 3809 E John St
# Geocoding: 904 Sturgus Ave S
# Geocoding: 9335 Sturtevant Ave S
# Geocoding: Belmont Ave E & Bellevue Pl E
# Geocoding: 200 Summit Ave E
# Geocoding: 2301 N Northlake Way
# Geocoding: 7531 34th Ave NW
# Geocoding: 105 NW 52nd St
# Geocoding: 12th Ave W & W Howe St
# Geocoding: 1698 E Union St
# Geocoding: 511 Boylston Ave E
# Geocoding: 2001 Fairview Ave E
# Geocoding: 10088 Waters Ave S
# Geocoding: 2401 6th Ave N
# Geocoding: 306 Bellevue Ave E
# Geocoding: 1818 Thorndyke Ave W
# Geocoding: 13002 10th Ave NE
# Geocoding: 2853 NW 58th St
# Geocoding: 2701 5th Ave
# Geocoding: 1800 Taylor Ave N
# Geocoding: 2821 12TH Ave S
# Geocoding: 1200 W Howe St
# Geocoding: 316 S Jackson St
# Geocoding: 5801 University Circle NE
# Geocoding: 4275 NE 125th St
# Geocoding: 4745 9th Ave NE
# Geocoding: 2605 W Galer St
# Geocoding: 7050 Beacon Ave S
# Geocoding: 2001 Western Ave
# Geocoding: 1059 NE Northgate Way
# Geocoding: 1737 NE 106th St
# Geocoding: 4408 NE 70th St
# Geocoding: 151 Lake Washington Blvd E
# Geocoding: 2700 NE 123rd St
# Geocoding: 1247 15th Ave E
# Geocoding: 1400 E Galer St
# Geocoding: 4219 Wallingford Ave N
# Geocoding: 1800 N Northlake Way
# Geocoding: 6920 34th Ave SW
# Geocoding: 4th Ave N & Ward St
# Geocoding: 7400 Sand Point Way NE
# Geocoding: 2300 Arboretum Dr E
# Geocoding: 1017 Lake Washington Blvd E
# Geocoding: 199 Alaskan Way S
# Geocoding: 1401 Alaskan Way
# Geocoding: 4035 Beach Dr SW
# Geocoding: 3025 NW 68th St
# Geocoding: 8126 31st Ave NE
# Geocoding: W Marginal Way SW & Highland Park Way SW
# Geocoding: 244 W Ewing St
# Geocoding: 2815 W Park Dr E
# Geocoding: 150 W Blaine St
# Geocoding: 4600 35th Ave SW
# Geocoding: 4432 35th Ave SW
# Geocoding: 9000 8th Ave SW
# Geocoding: Westlake Ave & Halladay St
# Geocoding: 401 Pine St
# Geocoding: 1900 Westlake Ave
# Geocoding: 1814 30th Ave
# Geocoding: 199 15th Ave E
# Geocoding: McGraw St. between 2nd Ave. N and Nobb Hill Ave. N
# Geocoding: 1000 N 50th St
# Geocoding: 750 N 50th St
# Geocoding: 700 N 50th St
# Geocoding: 835 Yesler Way
# Geocoding: 3650 Renton Ave S
# Geocoding: 3327 34th Ave S
# Done writing csv file

# %% [markdown]
# I tried to get a shapefile output in two different ways.  The first way I tried was to use ArcMap tools.  The 'MakeXYEventLayer' and 'FeatureClassToSHapefile' tools were able to produce a shapefile with th ecorresponding lat/lng coordinates but the file was not spatially referenced appropriately.  I was unable to determine a fix for this and so I tried a second method using shapely.  This was a method linked to in the assignment literature.  I encountered the same issue there.

# %%
import sys
sys.path.append('C:\\Program Files (x86)\\ArcGIS\\Desktop10.3\\bin')
sys.path.append('C:\\Program Files (x86)\\ArcGIS\\Desktop10.3\\arcpy')
sys.path.append('C:\\Program Files (x86)\\ArcGIS\\Desktop10.3\\ArcToolbox\\Scripts')
import arcpy

#set environment workspace and overwrite functions
arcpy.env.workspace = "U:/"
arcpy.env.overwriteOutput = True

latlngTab = "U:/GEOG458/Web scraper/Seattle_parks_geocode.csv"
sr = arcpy.SpatialReference(4326)

arcpy.arcpy.MakeXYEventLayer_management(latlngTab,"lat","lng","temp.lyr",sr)
arcpy.FeatureClassToShapefile_conversion('temp.lyr',"U:/")

print "conversion complete"
# Out:
# conversion complete

# %%
import csv
from shapely.geometry import Point, mapping
from fiona import collection

schema = { 'geometry': 'Point', 'properties': { 'Park Name': 'str' , 'Address': 'str'} }
with collection(
    "Seattle_Parks.shp", "w", "ESRI Shapefile", schema) as output:
    with open(geoDirectory, 'rb') as f:
        reader = csv.DictReader(f)
        for row in reader:
            point = Point(float(row['lng']), float(row['lat']))
            output.write({
                'properties': {
                    'Park Name': row['Park Name'],
                    'Address': row['Address']
                },
                'geometry': mapping(point)
            })

# %% [markdown]
# While running short on time I tried to use shapely/fiona to export the same information into a different file format (ie. GeoJSON) but encountered an error.

# %%
import csv
from shapely.geometry import Point, mapping
from fiona import collection

schema = { 'geometry': 'Point', 'properties': { 'Park Name': 'str' , 'Address': 'str'} }
with collection(
    "Seattle_Parks", "w", "GeoJSON", schema) as output:
    with open(geoDirectory, 'rb') as f:
        reader = csv.DictReader(f)
        for row in reader:
            point = Point(float(row['lng']), float(row['lat']))
            output.write({
                'properties': {
                    'Park Name': row['Park Name'],
                    'Address': row['Address']
                },
                'geometry': mapping(point)
            })
# Out:
# WARNING:Fiona:CPLE_NotSupported in dataset Seattle_Parks does not support layer creation option ENCODING
